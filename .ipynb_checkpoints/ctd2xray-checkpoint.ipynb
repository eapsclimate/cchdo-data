# %% [markdown]
# ### packages

# %%
from ctd2xray import cchdo
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ### data

# %%
target_pressure = np.arange(5., 6000., 10.)

# %%
ds = cchdo.open_cchdo_as_mfdataset\
('/home/cz2397/data/cchdo-ctd/208_09AR20120105_nc_ctd/*ctd.nc', target_pressure)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (pressure_i: 600, time: 95)
# Coordinates:
#   * pressure_i             (pressure_i) float64 5.0 15.0 25.0 35.0 45.0 55.0 ...
#     longitude              (time) float32 145.19 145.384 145.859 145.559 ...
#   * time                   (time) datetime64[ns] 2012-01-08T07:56:00 ...
#     latitude               (time) float32 -55.9965 -66.9107 -67.222 -67.1458 ...
# Data variables:
#     CTD_FLUOROUPCAST_i     (time, pressure_i) float64 0.6075 0.7275 0.842 ...
#     CTD_TRANSUPCAST_QC_i   (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_TRANS_i            (time, pressure_i) float64 96.66 96.75 96.8 96.89 ...
#     salinity_QC_i          (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     woce_time              (time) int16 756 1846 45 310 617 907 1146 1159 ...
#     CTD_FLUORO_i           (time, pressure_i) float64 0.2335 0.341 0.41 ...
#     temperature_i          (time, pressure_i) float64 2.73 2.708 2.675 2.585 ...
#     oxygen_i               (time, pressure_i) float64 333.6 332.8 332.3 ...
#     pressure_QC_i          (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_PAR_i              (time, pressure_i) float64 114.6 51.5 29.22 17.98 ...
#     CTD_TRANSUPCAST_i      (time, pressure_i) float64 95.44 95.32 95.29 95.3 ...
#     CTD_FLUOROUPCAST_QC_i  (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_PARUPCAST_QC_i     (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     woce_date              (time) int32 20120108 20120110 20120111 20120111 ...
#     salinity_i             (time, pressure_i) float64 33.79 33.79 33.79 ...
#     cast                   (time) |S40 '1                                       ' ...
#     station                (time) |S40 '001                                     ' ...
#     temperature_QC_i       (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_PARUPCAST_i        (time, pressure_i) float64 17.18 7.999 4.696 ...
#     CTD_PAR_QC_i           (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_FLUORO_QC_i        (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     oxygen_QC_i            (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_TRANS_QC_i         (time, pressure_i) float64 3.0 3.0 3.0 3.0 3.0 ...
# Attributes:
#     EXPOCODE: 09AR1203_1
#     Conventions: COARDS/WOCE
#     WOCE_VERSION: 3.0
#     WOCE_ID:
#     DATA_TYPE: WOCE CTD
#     STATION_NUMBER: 001
#     CAST_NUMBER: 1
#     BOTTOM_DEPTH_METERS: 2846
#     Creation_Time: 2013-10-16T23:53:54.663379Z
#     ORIGINAL_HEADER:
#     WOCE_CTD_FLAG_DESCRIPTION: ::1 = Not calibrated:2 = Acceptable measurement:3 = Questionable measurement:4 = Bad measurement:5 = Not reported:6 = Interpolated over >2 dbar interval:7 = Despiked:8 = Not assigned for CTD data:9 = Not sampled:

# %%
plt.plot(ds.longitude, ds.latitude, '.-')

# %%
ds_lat = ds.swap_dims({'time': 'latitude'})

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (pressure_i: 600, time: 95)
# Coordinates:
#   * pressure_i             (pressure_i) float64 5.0 15.0 25.0 35.0 45.0 55.0 ...
#     longitude              (time) float32 145.19 145.384 145.859 145.559 ...
#   * time                   (time) datetime64[ns] 2012-01-08T07:56:00 ...
#     latitude               (time) float32 -55.9965 -66.9107 -67.222 -67.1458 ...
# Data variables:
#     CTD_FLUOROUPCAST_i     (time, pressure_i) float64 0.6075 0.7275 0.842 ...
#     CTD_TRANSUPCAST_QC_i   (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_TRANS_i            (time, pressure_i) float64 96.66 96.75 96.8 96.89 ...
#     salinity_QC_i          (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     woce_time              (time) int16 756 1846 45 310 617 907 1146 1159 ...
#     CTD_FLUORO_i           (time, pressure_i) float64 0.2335 0.341 0.41 ...
#     temperature_i          (time, pressure_i) float64 2.73 2.708 2.675 2.585 ...
#     oxygen_i               (time, pressure_i) float64 333.6 332.8 332.3 ...
#     pressure_QC_i          (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_PAR_i              (time, pressure_i) float64 114.6 51.5 29.22 17.98 ...
#     CTD_TRANSUPCAST_i      (time, pressure_i) float64 95.44 95.32 95.29 95.3 ...
#     CTD_FLUOROUPCAST_QC_i  (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_PARUPCAST_QC_i     (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     woce_date              (time) int32 20120108 20120110 20120111 20120111 ...
#     salinity_i             (time, pressure_i) float64 33.79 33.79 33.79 ...
#     cast                   (time) |S40 '1                                       ' ...
#     station                (time) |S40 '001                                     ' ...
#     temperature_QC_i       (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_PARUPCAST_i        (time, pressure_i) float64 17.18 7.999 4.696 ...
#     CTD_PAR_QC_i           (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_FLUORO_QC_i        (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     oxygen_QC_i            (time, pressure_i) float64 2.0 2.0 2.0 2.0 2.0 ...
#     CTD_TRANS_QC_i         (time, pressure_i) float64 3.0 3.0 3.0 3.0 3.0 ...
# Attributes:
#     EXPOCODE: 09AR1203_1
#     Conventions: COARDS/WOCE
#     WOCE_VERSION: 3.0
#     WOCE_ID:
#     DATA_TYPE: WOCE CTD
#     STATION_NUMBER: 001
#     CAST_NUMBER: 1
#     BOTTOM_DEPTH_METERS: 2846
#     Creation_Time: 2013-10-16T23:53:54.663379Z
#     ORIGINAL_HEADER:
#     WOCE_CTD_FLAG_DESCRIPTION: ::1 = Not calibrated:2 = Acceptable measurement:3 = Questionable measurement:4 = Bad measurement:5 = Not reported:6 = Interpolated over >2 dbar interval:7 = Despiked:8 = Not assigned for CTD data:9 = Not sampled:

# %%
fig, ax = plt.subplots(figsize=(20, 8))
pt = ds.temperature_i.T.plot(yincrease=False, ax=ax, vmin=-2, vmax=10)
pt.colorbar.remove()
fig.autofmt_xdate()
plt.xlabel('$date$')
plt.ylabel('$pressure$')
plt.colorbar(pt).set_label("$temperature$")

# %%
fig, ax = plt.subplots(figsize=(20, 8))
pt_lat = ds_lat.temperature_i[30:].T.plot(yincrease=False, ax=ax, vmin=-2, vmax=10)
pt_lat.colorbar.remove()
fig.autofmt_xdate()
plt.xlabel('$latitude$')
plt.ylabel('$pressure$')
plt.colorbar(pt).set_label("$temperature$")

# %%
fig, ax = plt.subplots(figsize=(20, 8))
ps = ds.salinity_i.T.plot(yincrease=False, ax=ax, vmin=34, vmax=36)
ps.colorbar.remove()
fig.autofmt_xdate()
plt.xlabel('$date$')
plt.ylabel('$pressure$')
plt.colorbar(ps).set_label("$salinity$")

# %%
fig, ax = plt.subplots(figsize=(20, 8))
ps_lat = ds_lat.salinity_i.T.plot(yincrease=False, ax=ax, vmin=34, vmax=36)
ps_lat.colorbar.remove()
fig.autofmt_xdate()
plt.xlabel('$latitude$')
plt.ylabel('$pressure$')
plt.colorbar(ps).set_label("$salinity$")

# %%
fig, ax = plt.subplots(figsize=(20, 8))
po = ds.oxygen_i.T.plot(yincrease=False, ax=ax, vmin=150, vmax=350)
po.colorbar.remove()
fig.autofmt_xdate()
plt.xlabel('$date$')
plt.ylabel('$pressure$')
plt.colorbar(po).set_label("$oxygen$")

# %%
fig, ax = plt.subplots(figsize=(20, 8))
po_lat = ds_lat.oxygen_i.T.plot(yincrease=False, ax=ax, vmin=150, vmax=350)
po_lat.colorbar.remove()
fig.autofmt_xdate()
plt.xlabel('$latitude$')
plt.ylabel('$pressure$')
plt.colorbar(po).set_label("$oxygen$")

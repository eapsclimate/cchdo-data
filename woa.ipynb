# %%
import xarray as xr

# %%
ds = xr.open_dataset('/home/rpa/WOA_analysis/WOA13v2.nc', decode_times=False)
ds
# Out:
# <xarray.Dataset>
# Dimensions:             (depth: 102, lat: 160, lon: 360, nbounds: 2, time: 1)
# Coordinates:
#   * lat                 (lat) float32 -79.5 -78.5 -77.5 -76.5 -75.5 -74.5 ...
#   * lon                 (lon) float32 -179.5 -178.5 -177.5 -176.5 -175.5 ...
#   * depth               (depth) float32 0.0 5.0 10.0 15.0 20.0 25.0 30.0 ...
#   * time                (time) float32 6.0
#   * nbounds             (nbounds) int64 0 1
# Data variables:
#     crs                 int64 -2147483647
#     lat_bnds            (lat, nbounds) float32 -80.0 -79.0 -79.0 -78.0 -78.0 ...
#     lon_bnds            (lon, nbounds) float32 -180.0 -179.0 -179.0 -178.0 ...
#     depth_bnds          (depth, nbounds) float32 0.0 2.5 2.5 7.5 7.5 12.5 ...
#     climatology_bounds  (time, nbounds) float32 0.0 12.0
#     O_an                (time, depth, lat, lon) float64 nan nan nan nan nan ...
#     O_mn                (time, depth, lat, lon) float64 nan nan nan nan nan ...
# ...

# %%
ds.A_mn
# Out:
# <xarray.DataArray 'A_mn' (time: 1, depth: 102, lat: 160, lon: 360)>
# [5875200 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float32 -79.5 -78.5 -77.5 -76.5 -75.5 -74.5 -73.5 -72.5 ...
#   * lon      (lon) float32 -179.5 -178.5 -177.5 -176.5 -175.5 -174.5 -173.5 ...
#   * depth    (depth) float32 0.0 5.0 10.0 15.0 20.0 25.0 30.0 35.0 40.0 45.0 ...
#   * time     (time) float32 6.0
# Attributes:
#     standard_name: apparent_oxygen_utilization
#     long_name: Average of all unflagged interpolated values at each standard depth level for apparent_oxygen_utilization in each grid-square which contain at least one measurement.
#     cell_methods: area: mean depth: mean time: mean
#     grid_mapping: crs
#     units: milliliters_per_liter

# %%
# !ncdump -h /home/rpa/WOA_analysis/WOA13v2.nc
# Out:
# netcdf WOA13v2 {
# dimensions:
# 	lat = 160 ;
# 	nbounds = 2 ;
# 	lon = 360 ;
# 	depth = 102 ;
# 	time = 1 ;
# variables:
# 	int64 crs ;
# 		string crs:grid_mapping_name = "latitude_longitude" ;
# 		string crs:epsg_code = "EPSG:4326" ;
# 		crs:longitude_of_prime_meridian = 0.f ;
# 		crs:semi_major_axis = 6378137.f ;
# 		crs:inverse_flattening = 298.2572f ;
# 	float lat(lat) ;
# 		string lat:standard_name = "latitude" ;
# 		string lat:long_name = "latitude" ;
# 		string lat:units = "degrees_north" ;
# 		string lat:axis = "Y" ;
# 		string lat:bounds = "lat_bnds" ;
# 	float lat_bnds(lat, nbounds) ;
# 		string lat_bnds:comment = "latitude bounds" ;
# 	float lon(lon) ;
# 		string lon:standard_name = "longitude" ;
# 		string lon:long_name = "longitude" ;
# 		string lon:units = "degrees_east" ;
# 		string lon:axis = "X" ;
# 		string lon:bounds = "lon_bnds" ;
# 	float lon_bnds(lon, nbounds) ;
# 		string lon_bnds:comment = "longitude bounds" ;
# 	float depth(depth) ;
# ...

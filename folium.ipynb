# %% [markdown]
# ### packages ###

# %%
from pymongo import MongoClient
from tqdm import tqdm
import folium

# %% [markdown]
# ### rcs-ctd map ###

# %%
rcs_ctd = MongoClient().eddies.rcs_ctd

# %%
rcs_ctd.find_one()
# Out:
# {u'EDDYCODE': u'traj_1140-1170_0006642711-17',
#  u'EXPOCODE': u'18DD9601_1',
#  u'FILEPATH': u'/home/cz2397/data/cchdo-ctd/284_pr06_h_nc_ctd/pr06_h_prs1_00009_ctd.nc',
#  u'_id': ObjectId('581cd0732895ee1308aed6a2'),
#  u'eddy_cat': u'RCS',
#  u'eddy_dat': datetime.datetime(1996, 3, 2, 0, 0),
#  u'eddy_loc': {u'coordinates': [-145.34515380859375, 49.905670166015625],
#   u'type': u'Point'},
#  u'eddy_rad': 27663.885214132035,
#  u'expo_cas': u'9',
#  u'expo_cat': u'CTD',
#  u'expo_dat': datetime.datetime(1996, 3, 2, 11, 31),
#  u'expo_loc': {u'coordinates': [-144.9963, 50.009], u'type': u'Point'},
#  u'expo_sta': u'PRS1'}

# %%
map_rc = folium.Map(location=[0, 0], zoom_start=1)

# %%
for document in tqdm(rcs_ctd.find()):
    eddy_lat = document['eddy_loc']['coordinates'][1]
    eddy_lon = document['eddy_loc']['coordinates'][0]
    eddy_coo = [eddy_lat, eddy_lon]
    eddy_rad = document['eddy_rad']
    expo_lat = document['expo_loc']['coordinates'][1]
    expo_lon = document['expo_loc']['coordinates'][0]
    expo_coo = [expo_lat, expo_lon]
    eddy_inf = "eddy-id: " + document['EDDYCODE']
    expo_inf = "expo-id: " + document['EXPOCODE'] + '-' + document['expo_sta'] + '-' + document['expo_cas']
    folium.folium.Marker(eddy_coo, popup=eddy_inf).add_to(map_rc)
    folium.CircleMarker(eddy_coo, radius=eddy_rad).add_to(map_rc)
    folium.folium.Marker(expo_coo, popup=expo_inf).add_to(map_rc)
# Out:
# 869it [00:47, 18.46it/s]

# %%
map_rc

# %% [markdown]
# ### rcs-hyd map ###

# %%
rcs_hyd = MongoClient().eddies.rcs_hyd

# %%
rcs_hyd.find_one()
# Out:
# {u'EDDYCODE': u'traj_1140-1170_0006642711-17',
#  u'EXPOCODE': u'18DD9601_1',
#  u'FILEPATH': u'/home/cz2397/data/cchdo-hyd/247_pr06_h_nc_hyd/pr06_h_prs1_00002_hy1.nc',
#  u'_id': ObjectId('581cd12e2895ee1a074a4fe8'),
#  u'eddy_cat': u'RCS',
#  u'eddy_dat': datetime.datetime(1996, 3, 2, 0, 0),
#  u'eddy_loc': {u'coordinates': [-145.34515380859375, 49.905670166015625],
#   u'type': u'Point'},
#  u'eddy_rad': 27663.885214132035,
#  u'expo_cas': u'  2',
#  u'expo_cat': u'HYD',
#  u'expo_dat': datetime.datetime(1996, 2, 29, 10, 25),
#  u'expo_loc': {u'coordinates': [-144.9793, 49.9845], u'type': u'Point'},
#  u'expo_sta': u'  PRS1'}

# %%
map_rh = folium.Map(location=[0, 0], zoom_start=1)

# %%
for document in tqdm(rcs_hyd.find()):
    eddy_lat = document['eddy_loc']['coordinates'][1]
    eddy_lon = document['eddy_loc']['coordinates'][0]
    eddy_coo = [eddy_lat, eddy_lon]
    eddy_rad = document['eddy_rad']
    expo_lat = document['expo_loc']['coordinates'][1]
    expo_lon = document['expo_loc']['coordinates'][0]
    expo_coo = [expo_lat, expo_lon]
    eddy_inf = "eddy-id: " + document['EDDYCODE']
    expo_inf = "expo-id: " + document['EXPOCODE'] + '-' + document['expo_sta'] + '-' + document['expo_cas']
    folium.folium.Marker(eddy_coo, popup=eddy_inf).add_to(map_rh)
    folium.CircleMarker(eddy_coo, radius=eddy_rad).add_to(map_rh)
    folium.folium.Marker(expo_coo, popup=expo_inf).add_to(map_rh)
# Out:
# 849it [00:46, 18.40it/s]

# %%
map_rh
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# ### ssh-ctd map ###

# %%
ssh_ctd = MongoClient().eddies.ssh_ctd

# %%
ssh_ctd.find_one()
# Out:
# {u'EDDYCODE': u'182211-125',
#  u'EXPOCODE': u'33H420090207',
#  u'FILEPATH': u'/home/cz2397/data/cchdo-ctd/bats-ars20_61124_00001_ctd.nc',
#  u'_id': ObjectId('581cd08a2895ee1a9ca9b6aa'),
#  u'eddy_cat': u'SSH',
#  u'eddy_dat': datetime.datetime(2009, 2, 4, 12, 0),
#  u'eddy_loc': {u'coordinates': [-64.04000854492188, 31.863500595092773],
#   u'type': u'Point'},
#  u'eddy_rad': 143954.0,
#  u'expo_cas': u'001',
#  u'expo_cat': u'CTD',
#  u'expo_dat': datetime.datetime(2009, 2, 7, 15, 14),
#  u'expo_loc': {u'coordinates': [-64.498, 32.163], u'type': u'Point'},
#  u'expo_sta': u'61124'}

# %%
map_sc = folium.Map(location=[0, 0], zoom_start=1)

# %%
for document in tqdm(ssh_ctd.find()):
    eddy_lat = document['eddy_loc']['coordinates'][1]
    eddy_lon = document['eddy_loc']['coordinates'][0]
    eddy_coo = [eddy_lat, eddy_lon]
    eddy_rad = document['eddy_rad']
    expo_lat = document['expo_loc']['coordinates'][1]
    expo_lon = document['expo_loc']['coordinates'][0]
    expo_coo = [expo_lat, expo_lon]
    eddy_inf = "eddy-id: " + document['EDDYCODE']
    expo_inf = "expo-id: " + document['EXPOCODE'] + '-' + document['expo_sta'] + '-' + document['expo_cas']
    folium.folium.Marker(eddy_coo, popup=eddy_inf).add_to(map_sc)
    folium.CircleMarker(eddy_coo, radius=eddy_rad).add_to(map_sc)
    folium.folium.Marker(expo_coo, popup=expo_inf).add_to(map_sc)
# Out:
# 40861it [38:04, 17.88it/s]

# %%
map_sc

# %% [markdown]
# ### ssh-hyd map ###

# %%
ssh_hyd = MongoClient().eddies.ssh_hyd

# %%
ssh_hyd.find_one()
# Out:
# {u'EDDYCODE': u'33740-45',
#  u'EXPOCODE': u'3175GP895_2',
#  u'FILEPATH': u'/home/cz2397/data/cchdo-hyd/pr16_q_00035_00001_hy1.nc',
#  u'_id': ObjectId('581cd09c2895ee1b393bce0a'),
#  u'eddy_cat': u'SSH',
#  u'eddy_dat': datetime.datetime(1996, 1, 11, 12, 0),
#  u'eddy_loc': {u'coordinates': [-109.47601318359375, 3.7007598876953125],
#   u'type': u'Point'},
#  u'eddy_rad': 204492.0,
#  u'expo_cas': u'  1',
#  u'expo_cat': u'HYD',
#  u'expo_dat': datetime.datetime(1996, 1, 10, 4, 57),
#  u'expo_loc': {u'coordinates': [-110.1367, 2.0433], u'type': u'Point'},
#  u'expo_sta': u'    35'}

# %%
map_sh = folium.Map(location=[0, 0], zoom_start=1)

# %%
for document in tqdm(ssh_hyd.find()):
    eddy_lat = document['eddy_loc']['coordinates'][1]
    eddy_lon = document['eddy_loc']['coordinates'][0]
    eddy_coo = [eddy_lat, eddy_lon]
    eddy_rad = document['eddy_rad']
    expo_lat = document['expo_loc']['coordinates'][1]
    expo_lon = document['expo_loc']['coordinates'][0]
    expo_coo = [expo_lat, expo_lon]
    eddy_inf = "eddy-id: " + document['EDDYCODE']
    expo_inf = "expo-id: " + document['EXPOCODE'] + '-' + document['expo_sta'] + '-' + document['expo_cas']
    folium.folium.Marker(eddy_coo, popup=eddy_inf).add_to(map_sh)
    folium.CircleMarker(eddy_coo, radius=eddy_rad).add_to(map_sh)
    folium.folium.Marker(expo_coo, popup=expo_inf).add_to(map_sh)
# Out:
# 22640it [21:33, 17.59it/s]

# %%
map_sh
